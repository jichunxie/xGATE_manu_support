# %%
import os
os.environ['PYTHONHASHSEED'] = '0' 
import random
random.seed(12)
import numpy as np
np.random.seed(12)
import torch
torch.manual_seed(12)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

import pandas as pd
import mygene
import sys, importlib
# Robust import for xGATE package (try 'xGATE' then 'xgate')
for _pkg in ("xGATE", "xgate"):
    try:
        utilities = importlib.import_module(f"{_pkg}.utilities")
        for _name in dir(utilities):
            if not _name.startswith("_"):
                globals()[_name] = getattr(utilities, _name)
        break
    except Exception:
        continue
else:
    raise ImportError("Could not import xGATE.utilities. Install the xGATE Python package (see README) or ensure it's on PYTHONPATH.")

test_pathways = [
    "Autophagy",
    "Protein processing in endoplasmic reticulum",
    "mTOR signaling pathway",
    "MAPK signaling pathway",
    "Apoptosis",
    "Longevity regulating pathway",
    "HIF-1 signaling pathway",
    "AMPK signaling pathway",
    "Phagosome",
    "PPAR signaling pathway",
    "FoxO signaling pathway",
    "cGMP-PKG signaling pathway",
    "Cytokine-cytokine receptor interaction",
    "Mineral absorption",
    "Antigen processing and presentation",
    "Rap1 signaling pathway",
    "Ribosome",
    "Protein digestion and absorption",
    "PI3K-Akt signaling pathway",
    "Insulin signaling pathway",
    "Oxidative phosphorylation",
    "Pancreatic secretion",
    "Salmonella infection",
    "Bacterial invasion of epithelial cells",
    "Pathogenic Escherichia coli infection",
    "Thyroid cancer",
    "Shigellosis"
]

print("T1D Pancreas Group")
# Load your count_matrix DataFrame
count_matrix = pd.read_csv("/work/of21_work/pancreas_t1d_final.csv", index_col=0)
count_filtered = count_matrix

row_means = np.mean(count_filtered, axis=1)

# Check if any row means are 0 or 1
rows_with_mean_zero_or_one = (row_means == 0) | (row_means == 1)

# If you need the indices of such rows
indices = np.where(rows_with_mean_zero_or_one)[0]

row_means = np.mean(count_filtered, axis=1)

# Identify the indices of rows with mean 0 or 1
rows_to_remove = (row_means == 0) | (row_means == 1)

# Remove these rows
count_filtered = count_filtered[~rows_to_remove]


# Uncomment these lines if adj_matrix is not already saved
'''
df = pd.DataFrame(count_filtered)
so = create_sifinet_object(df, rowfeature= True)
so = quantile_thres2(so)
so = cal_coexp(so, X = so.data_thres['dt'], X_full = so.data_thres['dt'])
so = create_network(so, alpha=0.05, manual=False, least_edge_prop=0.01)
so = filter_lowexp(so, t1=10, t2=0.9, t3=0.9)

adj_matrix = so.coexp


sif_ob_test = so

# Perform the element-wise comparison and assignment
adj_matrix = pd.DataFrame(np.where(
    np.abs(sif_ob_test.coexp - sif_ob_test.est_ms['mean']) > sif_ob_test.thres,
    np.abs(sif_ob_test.coexp),
    0
))

adj_matrix.index = df.index

adj_matrix.columns = df.index

adj_matrix = convert_gene_ids(adj_matrix, "ensembl")

adj_matrix.to_csv('/work/of21_work/adj_matrix_pancreas_t1d_final.csv', index=True)
'''
adj_matrix = pd.read_csv('/work/of21_work/adj_matrix_pancreas_t1d_final.csv', index_col=0)

G_s = utilities.create_network_from_adj_matrix(adj_matrix)

categorized_pathways = utilities.get_categorized_pathways()

pathway_results_t1d = utilities.analyze_pathways(G_s, test_pathways, categorized_pathways ,num_walks=200, max_walk_length = 200, null_dist_size = 200)

print(pathway_results_t1d)
# Out:
# T1D Pancreas Group
# Pathway: Autophagy
# p-value: 0.6368159203980099
# Z-Score: -0.35163264886405754
#
# Pathway: Protein processing in endoplasmic reticulum
# p-value: 0.05472636815920398
# Z-Score: 1.3173599088589891
#
# Pathway: mTOR signaling pathway
# p-value: 0.7213930348258707
# Z-Score: -0.4286009647747341
#
# Pathway: MAPK signaling pathway
# p-value: 0.26865671641791045
# Z-Score: 0.1323158631067433
#
# Pathway: Apoptosis
# p-value: 0.004975124378109453
# Z-Score: 10.147080240990489
#
# Pathway: Longevity regulating pathway
# p-value: 0.5074626865671642
# Z-Score: -0.14666455641830603
#
# Pathway: HIF-1 signaling pathway
# p-value: 0.11940298507462686
# Z-Score: 0.20261336133822222
#
# Pathway: AMPK signaling pathway
# p-value: 0.8208955223880597
# Z-Score: -0.4945131492414555
#
# Pathway: Phagosome
# p-value: 0.004975124378109453
# Z-Score: 148.25147600723724
#
# Pathway: PPAR signaling pathway
# p-value: 0.12935323383084577
# Z-Score: 0.17511657506381004
#
# Pathway: FoxO signaling pathway
# p-value: 0.5223880597014925
# Z-Score: -0.34237015591423353
#
# Pathway: cGMP-PKG signaling pathway
# p-value: 0.06965174129353234
# Z-Score: 0.76016077460267
#
# Pathway: Cytokine-cytokine receptor interaction
# p-value: 0.009950248756218905
# Z-Score: 8.682846777241206
#
# Pathway: Mineral absorption
# p-value: 0.4527363184079602
# Z-Score: -0.19499817838906217
#
# Pathway: Antigen processing and presentation
# p-value: 0.004975124378109453
# Z-Score: 505.3710466771278
#
# Pathway: Rap1 signaling pathway
# p-value: 0.07960199004975124
# Z-Score: 0.8043659897380112
#
# Pathway: Ribosome
# p-value: 0.004975124378109453
# Z-Score: 6123971.257849845
#
# Pathway: Protein digestion and absorption
# p-value: 0.004975124378109453
# Z-Score: 31.060392641886683
#
# Pathway: PI3K-Akt signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 12.905724237065433
#
# Pathway: Insulin signaling pathway
# p-value: 0.7611940298507462
# Z-Score: -0.6414564169123358
#
# Pathway: Oxidative phosphorylation
# p-value: 0.004975124378109453
# Z-Score: 150028723412.52838
#
# Pathway: Pancreatic secretion
# p-value: 0.01990049751243781
# Z-Score: 3.1492474607061247
#
# Pathway: Salmonella infection
# p-value: 0.263681592039801
# Z-Score: 0.04056445540493032
#
# Pathway: Bacterial invasion of epithelial cells
# p-value: 0.07462686567164178
# Z-Score: 0.36688443975356694
#
# Pathway: Pathogenic Escherichia coli infection
# p-value: 0.1044776119402985
# Z-Score: 0.07604086887263539
#
# Pathway: Thyroid cancer
# p-value: 0.8258706467661692
# Z-Score: -0.34559490896154205
#
# Pathway: Shigellosis
# p-value: 0.6368159203980099
# Z-Score: -0.30397302400551374
#
#                                         pathway   p-value       z-score
# 0                                     Autophagy  0.636816 -3.516326e-01
# 1   Protein processing in endoplasmic reticulum  0.054726  1.317360e+00
# 2                        mTOR signaling pathway  0.721393 -4.286010e-01
# 3                        MAPK signaling pathway  0.268657  1.323159e-01
# 4                                     Apoptosis  0.004975  1.014708e+01
# 5                  Longevity regulating pathway  0.507463 -1.466646e-01
# 6                       HIF-1 signaling pathway  0.119403  2.026134e-01
# 7                        AMPK signaling pathway  0.820896 -4.945131e-01
# 8                                     Phagosome  0.004975  1.482515e+02
# 9                        PPAR signaling pathway  0.129353  1.751166e-01
# 10                       FoxO signaling pathway  0.522388 -3.423702e-01
# 11                   cGMP-PKG signaling pathway  0.069652  7.601608e-01
# 12       Cytokine-cytokine receptor interaction  0.009950  8.682847e+00
# 13                           Mineral absorption  0.452736 -1.949982e-01
# 14          Antigen processing and presentation  0.004975  5.053710e+02
# 15                       Rap1 signaling pathway  0.079602  8.043660e-01
# 16                                     Ribosome  0.004975  6.123971e+06
# 17             Protein digestion and absorption  0.004975  3.106039e+01
# 18                   PI3K-Akt signaling pathway  0.004975  1.290572e+01
# 19                    Insulin signaling pathway  0.761194 -6.414564e-01
# 20                    Oxidative phosphorylation  0.004975  1.500287e+11
# 21                         Pancreatic secretion  0.019900  3.149247e+00
# 22                         Salmonella infection  0.263682  4.056446e-02
# 23       Bacterial invasion of epithelial cells  0.074627  3.668844e-01
# 24        Pathogenic Escherichia coli infection  0.104478  7.604087e-02
# 25                               Thyroid cancer  0.825871 -3.455949e-01
# 26                                  Shigellosis  0.636816 -3.039730e-01

# %%
print("Control Pancreas Group")
# Load your count_matrix DataFrame
count_matrix = pd.read_csv("/work/of21_work/pancreas_ctrl_final.csv", index_col=0)
count_filtered = count_matrix

row_means = np.mean(count_filtered, axis=1)

# Check if any row means are 0 or 1
rows_with_mean_zero_or_one = (row_means == 0) | (row_means == 1)

# If you need the indices of such rows
indices = np.where(rows_with_mean_zero_or_one)[0]

row_means = np.mean(count_filtered, axis=1)

# Identify the indices of rows with mean 0 or 1
rows_to_remove = (row_means == 0) | (row_means == 1)

# Remove these rows
count_filtered = count_filtered[~rows_to_remove]


# Uncomment these lines if adj_matrix is not already saved
'''
df = pd.DataFrame(count_filtered)
so = create_sifinet_object(df, rowfeature= True)
so = quantile_thres2(so)
so = cal_coexp(so, X = so.data_thres['dt'], X_full = so.data_thres['dt'])
so = create_network(so, alpha=0.05, manual=False, least_edge_prop=0.01)
so = filter_lowexp(so, t1=10, t2=0.9, t3=0.9)

adj_matrix = so.coexp


sif_ob_test = so

# Perform the element-wise comparison and assignment
adj_matrix = pd.DataFrame(np.where(
    np.abs(sif_ob_test.coexp - sif_ob_test.est_ms['mean']) > sif_ob_test.thres,
    np.abs(sif_ob_test.coexp),
    0
))

adj_matrix.index = df.index

adj_matrix.columns = df.index

adj_matrix = convert_gene_ids(adj_matrix, "ensembl")

adj_matrix.to_csv('/work/of21_work/adj_matrix_pancreas_ctrl_final.csv', index=True)
'''

adj_matrix = pd.read_csv('/work/of21_work/adj_matrix_pancreas_ctrl_final.csv', index_col=0)

G_s = utilities.create_network_from_adj_matrix(adj_matrix)


categorized_pathways = utilities.get_categorized_pathways()

pathway_results_ctrl = utilities.analyze_pathways(G_s, test_pathways, categorized_pathways ,num_walks=200, max_walk_length = 200, null_dist_size = 200)
print(pathway_results_ctrl)
# Out:
# Control Pancreas Group
# Pathway: Autophagy
# p-value: 0.004975124378109453
# Z-Score: 22.610136897265004
#
# Pathway: Protein processing in endoplasmic reticulum
# p-value: 0.004975124378109453
# Z-Score: 12.109679275164897
#
# Pathway: mTOR signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 9.848763629874657
#
# Pathway: MAPK signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 44.9610092928238
#
# Pathway: Apoptosis
# p-value: 0.208955223880597
# Z-Score: -0.09096115558999333
#
# Pathway: Longevity regulating pathway
# p-value: 0.004975124378109453
# Z-Score: 21.049610599736035
#
# Pathway: HIF-1 signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 19.43276744695546
#
# Pathway: AMPK signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 25.24494315567388
#
# Pathway: Phagosome
# p-value: 0.004975124378109453
# Z-Score: 24.168942949785972
#
# Pathway: PPAR signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 10.418619162837803
#
# Pathway: FoxO signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 18.55541907052203
#
# Pathway: cGMP-PKG signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 61.16949611369014
#
# Pathway: Cytokine-cytokine receptor interaction
# p-value: 0.22885572139303484
# Z-Score: -0.08428232161226629
#
# Pathway: Mineral absorption
# p-value: 0.01990049751243781
# Z-Score: 0.6976148775012556
#
# Pathway: Antigen processing and presentation
# p-value: 0.004975124378109453
# Z-Score: 110.11483729242255
#
# Pathway: Rap1 signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 26.608840907858948
#
# Pathway: Ribosome
# p-value: 0.004975124378109453
# Z-Score: 2868460.369490699
#
# Pathway: Protein digestion and absorption
# p-value: 0.004975124378109453
# Z-Score: 22.04257798872127
#
# Pathway: PI3K-Akt signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 84.90661986885631
#
# Pathway: Insulin signaling pathway
# p-value: 0.004975124378109453
# Z-Score: 38.987164293669736
#
# Pathway: Oxidative phosphorylation
# p-value: 0.004975124378109453
# Z-Score: 85.69029960220226
#
# Pathway: Pancreatic secretion
# p-value: 0.004975124378109453
# Z-Score: 35.582318701126944
#
# Pathway: Salmonella infection
# p-value: 0.10945273631840796
# Z-Score: 0.3231198588776234
#
# Pathway: Bacterial invasion of epithelial cells
# p-value: 0.48258706467661694
# Z-Score: -0.2510681187164788
#
# Pathway: Pathogenic Escherichia coli infection
# p-value: 0.0945273631840796
# Z-Score: 0.08719234885261558
#
# Pathway: Thyroid cancer
# p-value: 0.19900497512437812
# Z-Score: -0.12929254032303134
#
# Pathway: Shigellosis
# p-value: 0.24875621890547264
# Z-Score: -0.07305237177600209
#
#                                         pathway   p-value       z-score
# 0                                     Autophagy  0.004975  2.261014e+01
# 1   Protein processing in endoplasmic reticulum  0.004975  1.210968e+01
# 2                        mTOR signaling pathway  0.004975  9.848764e+00
# 3                        MAPK signaling pathway  0.004975  4.496101e+01
# 4                                     Apoptosis  0.208955 -9.096116e-02
# 5                  Longevity regulating pathway  0.004975  2.104961e+01
# 6                       HIF-1 signaling pathway  0.004975  1.943277e+01
# 7                        AMPK signaling pathway  0.004975  2.524494e+01
# 8                                     Phagosome  0.004975  2.416894e+01
# 9                        PPAR signaling pathway  0.004975  1.041862e+01
# 10                       FoxO signaling pathway  0.004975  1.855542e+01
# 11                   cGMP-PKG signaling pathway  0.004975  6.116950e+01
# 12       Cytokine-cytokine receptor interaction  0.228856 -8.428232e-02
# 13                           Mineral absorption  0.019900  6.976149e-01
# 14          Antigen processing and presentation  0.004975  1.101148e+02
# 15                       Rap1 signaling pathway  0.004975  2.660884e+01
# 16                                     Ribosome  0.004975  2.868460e+06
# 17             Protein digestion and absorption  0.004975  2.204258e+01
# 18                   PI3K-Akt signaling pathway  0.004975  8.490662e+01
# 19                    Insulin signaling pathway  0.004975  3.898716e+01
# 20                    Oxidative phosphorylation  0.004975  8.569030e+01
# 21                         Pancreatic secretion  0.004975  3.558232e+01
# 22                         Salmonella infection  0.109453  3.231199e-01
# 23       Bacterial invasion of epithelial cells  0.482587 -2.510681e-01
# 24        Pathogenic Escherichia coli infection  0.094527  8.719235e-02
# 25                               Thyroid cancer  0.199005 -1.292925e-01
# 26                                  Shigellosis  0.248756 -7.305237e-02
